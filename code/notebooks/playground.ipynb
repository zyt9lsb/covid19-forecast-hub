# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_time_series/time_series_covid19_deaths_US.csv")

# %%
fips_codes = pd.read_csv('../../data-locations/locations.csv')

# %%
state_agg = df.groupby(['Province_State']).agg()
us_nat = df.groupby(['Country_Region']).sum()
df_state_nat = state_agg.append(us_nat)

# %%
df_state_nat['FIPS'] = df_state_nat['FIPS'].astype(np.int32)

# %%
df_state_nat[df_state_nat['FIPS'].notna()]
# Out:
#                                    UID    code3       FIPS            Lat  \
# Alabama                     5796241491    57960     241491    2203.246784
# Alaska                      2604232344    26040     232344    1747.579877
# American Samoa                      16       16         60     -14.271000
# Arizona                     1428230216    14280     230216     505.138555
# Arkansas                    6468550635    64680     550635    2618.391704
# California                  5040521376    50400     521376    2194.949775
# Colorado                    5544685999    55440     685999    2491.870366
# Connecticut                  840242082     8400     242082     332.909441
# Delaware                     420200029     4200     200029     117.327830
# Diamond Princess              84088888      840      88888       0.000000
# District of Columbia         252181023     2520     181023      38.904178
# Florida                     5796978574    57960     978574    1939.030577
# ...

# %%
df.iloc[:15, :15]
# Out:
#          UID iso2 iso3  code3    FIPS    Admin2            Province_State  \
# 0         16   AS  ASM     16    60.0       NaN            American Samoa
# 1        316   GU  GUM    316    66.0       NaN                      Guam
# 2        580   MP  MNP    580    69.0       NaN  Northern Mariana Islands
# 3        630   PR  PRI    630    72.0       NaN               Puerto Rico
# 4        850   VI  VIR    850    78.0       NaN            Virgin Islands
# 5   84001001   US  USA    840  1001.0   Autauga                   Alabama
# 6   84001003   US  USA    840  1003.0   Baldwin                   Alabama
# 7   84001005   US  USA    840  1005.0   Barbour                   Alabama
# 8   84001007   US  USA    840  1007.0      Bibb                   Alabama
# 9   84001009   US  USA    840  1009.0    Blount                   Alabama
# 10  84001011   US  USA    840  1011.0   Bullock                   Alabama
# 11  84001013   US  USA    840  1013.0    Butler                   Alabama
# ...
